# %% [markdown]
# <a href="https://colab.research.google.com/github/jaydeshmukh411/python2026/blob/main/Exception_Handling_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python program to handle a ZeroDivisionError exception when dividing a number by zero.

# %%
try:
  a = int(input("Enter integer: "))
  b = int(input("Enter integer: "))

  print(a/b)

except ZeroDivisionError:
  print("Can't be divided by 0")
# Out:
# Enter integer: 1
# Enter integer: 1
# 1.0

# %% [markdown]
# 2. Write a Python program that prompts the user to input an integer and raises a ValueError exception if the input is not a valid integer.

# %%
try:
  a = int(input("Enter an integer:"))
  print(a)

except ValueError:
  print("Please enter a valid integer")
# Out:
# Enter an integer:1
# 1

# %% [markdown]
# 3. Write a Python program that opens a file and handles a FileNotFoundError exception if the file does not exist.

# %%
try:
  with open('sample.txt','r') as f:
    f.read()
except FileNotFoundError:
  print("File not found")
# Out:
# File not found

# %% [markdown]
# 4. Write a Python program that prompts the user to input two numbers and raises a TypeError exception if the inputs are not numerical.

# %%
try:
    a = float(input("Enter first number: "))
    b = float(input("Enter second number: "))

    print("Sum:", a + b)

except ValueError:
    raise TypeError("Inputs must be numerical!")
# Out:
# Enter first number: a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3516/665762888.py in <cell line: 0>()
#       1 try:
# ----> 2     a = float(input("Enter first number: "))
#       3     b = float(input("Enter second number: "))
#
# ValueError: could not convert string to float: 'a'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3516/665762888.py in <cell line: 0>()
#       6
#       7 except ValueError:
# ----> 8     raise TypeError("Inputs must be numerical!")
#
# TypeError: Inputs must be numerical!

# %% [markdown]
# 5. Write a Python program that opens a file and handles a PermissionError exception if there is a permission issue.

# %%
try:
    file = open("example.txt", "r")
    content = file.read()
    print(content)
    file.close()

except PermissionError:
    print("You don't have permission to access this file!")

except FileNotFoundError:
    print("File not found!")
# Out:
# Error: File not found!

# %% [markdown]
# 6. Write a Python program that executes an operation on a list and handles an IndexError exception if the index is out of range.

# %%
try:
  L = [1,2,3,4]
  a = L[100]

except IndexError:
  print("Index out of range")
# Out:
# Index out of range

# %% [markdown]
# 7. Write a Python program that executes division and handles an ArithmeticError exception if there is an arithmetic error.

# %%
try:
    a = float(input("Enter numerator: "))
    b = float(input("Enter denominator: "))

    result = a / b
    print( result)

except ArithmeticError:
    print("Arithmetic operation failed")
# Out:
# Enter numerator: 1
# Enter denominator: 1000000000000000000000000
# 1.0000000000000001e-24
